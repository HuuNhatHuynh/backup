# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
results = np.array([[94.37916666666666, 99.63541666666667, 76.19166564941406, 76.7562484741211],
                   [92.63749999999999, 99.775, 81.03541564941406, 84.8187484741211],
                   [95.7666666666666, 99.8375, 83.7874984741211, 89.92292022705078],
                   [94.22291666666666, 99.86666666666667, 86.01874542236328, 93.59791564941406],
                   [94.39166666666667, 99.84375, 87.11458587646484, 95.88749694824219]])

# %%
snr = [0, 5, 10, 15, 20]
plt.plot(snr, results[:, 0], label='DA-MUSIC')
plt.plot(snr, results[:, 1], label='ECNet')
plt.plot(snr, results[:, 2], label='AIC')
plt.plot(snr, results[:, 3], label='MDL')
plt.xlabel("SNR (dB)")
plt.ylabel("Accuracy (%)")
plt.legend()
plt.plot()
# Out:
# []
