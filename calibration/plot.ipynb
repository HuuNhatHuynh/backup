# %%
import matplotlib.pyplot as plt 
plt.rcParams['figure.dpi'] = 200

# %%
SNR = [0, 5, 10, 15, 20, 25]
model1 = [0.07135139126330614, 0.06976923136971891, 0.06579169281758368, 0.06955711194314063, 0.06762061722110957, 0.06905102671589702]
model2 = [0.0877103682141751, 0.08518025209195912, 0.08163000899367034, 0.08151811407878995, 0.08436370803974569, 0.08109643612988293]
model3 = [0.0683275694027543, 0.06673941493500024, 0.06276667374186218, 0.06498096324503422, 0.0639564588200301, 0.0653957404429093]

# %%
plt.plot(SNR, model1, color='red', label='Model 1')
plt.plot(SNR, model2, color='green', label='Model 2')
plt.plot(SNR, model3, color='blue', label='Model 3')
plt.xlabel('SNR (dB)')
plt.ylabel('RMSE (rad)')
plt.legend()
plt.grid(True)
plt.show()
